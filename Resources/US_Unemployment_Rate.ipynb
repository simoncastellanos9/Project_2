# %%
# Dependencies and Set up
import pandas as pd 
import requests
from bs4 import BeautifulSoup

# API
import time
import numpy as np
from pprint import pprint

# In case you change unix timestamp
from datetime import datetime
from pytz import timezone

# %%
# File to Load 
file_to_load = '/Users/karlaflores/Desktop/Git/Project_2/Resources/KWH_Houston.csv'
kwh_houston = pd.read_csv(file_to_load)
kwh_houston
# Out:
#           DATE APUS37B72610
# 0    11/1/1978        0.032
# 1    12/1/1978        0.034
# 2     1/1/1979        0.035
# 3     2/1/1979        0.036
# 4     3/1/1979        0.038
# ..         ...          ...
# 507   2/1/2021        0.143
# 508   3/1/2021        0.144
# 509   4/1/2021        0.141
# 510   5/1/2021        0.138
# 511   6/1/2021        0.138
#
# [512 rows x 2 columns]

# %%
# File to Load 
file_to_load = '/Users/karlaflores/Desktop/Git/Project_2/Resources/Houston_Weather_NOOA_NCDC.csv'
w_houston = pd.read_csv(file_to_load)

# %%
w_houston = w_houston[['DATE', 'STATION', 'NAME', 'TMAX', 'TMIN', 'TOBS']]
# Out:
#             DATE      STATION                                            NAME  \
# 0      12/1/1990  USC00414333  HOUSTON NATIONAL WEATHER SERVICE OFFICE, TX US
# 1      12/2/1990  USC00414333  HOUSTON NATIONAL WEATHER SERVICE OFFICE, TX US
# 2      12/3/1990  USC00414333  HOUSTON NATIONAL WEATHER SERVICE OFFICE, TX US
# 3      12/4/1990  USC00414333  HOUSTON NATIONAL WEATHER SERVICE OFFICE, TX US
# 4      12/5/1990  USC00414333  HOUSTON NATIONAL WEATHER SERVICE OFFICE, TX US
# ...          ...          ...                                             ...
# 11119   7/9/2021  USC00414333  HOUSTON NATIONAL WEATHER SERVICE OFFICE, TX US
# 11120  7/10/2021  USC00414333  HOUSTON NATIONAL WEATHER SERVICE OFFICE, TX US
# 11121  7/11/2021  USC00414333  HOUSTON NATIONAL WEATHER SERVICE OFFICE, TX US
# 11122  7/12/2021  USC00414333  HOUSTON NATIONAL WEATHER SERVICE OFFICE, TX US
# 11123  7/13/2021  USC00414333  HOUSTON NATIONAL WEATHER SERVICE OFFICE, TX US
#
#        TMAX  TMIN  TOBS
# ...

# %%
# Get the response in the form of html
url='https://www.multpl.com/unemployment/table/by-year'
response=requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
# Parse data from the html into a beautifulsoup object
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find_all('table')
table
# Out:
# [<table id="datatable">
#  <tr>
#  <th class="left">Date</th>
#  <th class="right">
#  <span class="title">
#  Rate
#  </span>
#  <span class="value">Value</span>
#  </th>
#  </tr>
#  <tr class="odd">
#  <td class="left">May 1, 2021</td>
#  <td class="right">5.80%
#
#  </td>
#  </tr>
#  <tr class="even">
#  <td class="left">Jan 1, 2021</td>
#  <td class="right">6.30%
#
#  </td>
#  </tr>
#  <tr class="odd">
#  <td class="left">Jan 1, 2020</td>
#  <td class="right">3.50%
#
#  </td>
#  </tr>
#  <tr class="even">
#  <td class="left">Jan 1, 2019</td>
#  <td class="right">4.00%
#
#  </td>
#  </tr>
#  <tr class="odd">
#  <td class="left">Jan 1, 2018</td>
#  <td class="right">4.00%
#
#  </td>
#  </tr>
#  <tr class="even">
#  <td class="left">Jan 1, 2017</td>
#  <td class="right">4.70%
#
#  </td>
#  </tr>
#  <tr class="odd">
#  <td class="left">Jan 1, 2016</td>
#  <td class="right">4.80%
#
#  </td>
#  </tr>
#  <tr class="even">
#  <td class="left">Jan 1, 2015</td>
#  <td class="right">5.70%
# ...

# %%
# Convert html table
us_unemployment_rate = pd.read_html(str(table))

# Convert list to dataframe
us_unemployment_rate =pd.DataFrame(us_unemployment_rate[0])
us_unemployment_rate
# Out:
#            Date Rate Value
# 0   May 1, 2021      5.80%
# 1   Jan 1, 2021      6.30%
# 2   Jan 1, 2020      3.50%
# 3   Jan 1, 2019      4.00%
# 4   Jan 1, 2018      4.00%
# ..          ...        ...
# 70  Jan 1, 1952      3.20%
# 71  Jan 1, 1951      3.70%
# 72  Jan 1, 1950      6.50%
# 73  Jan 1, 1949      4.30%
# 74  Jan 1, 1948      3.40%
#
# [75 rows x 2 columns]

# %%
us_unemployment_rate.dtypes
# Out:
# Date          object
# Rate Value    object
# dtype: object

# %%
us_unemployment_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        75 non-null     object
#  1   Rate Value  75 non-null     object
# dtypes: object(2)
# memory usage: 1.3+ KB

# %%
# us_unemployment_rate = us_unemployment_rate["Date"].dt.strftime("%m/%d/%y")

# %%
#
